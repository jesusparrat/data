# %% [markdown]
# # Tay-tanic

# %%
# Importamos las librerías necesarias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creamos el Dataframe a partir del dataset en CSV
df = pd.read_csv('titanic.csv')
# Configuramos el ID del pasajero como índice
df = df.set_index('PassengerId')
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df = df.drop(['Name','SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], axis = 1)
df
# Out:
#              Survived  Pclass     Sex   Age
# PassengerId
# 1                   0       3    male  22.0
# 2                   1       1  female  38.0
# 3                   1       3  female  26.0
# 4                   1       1  female  35.0
# 5                   0       3    male  35.0
# ...               ...     ...     ...   ...
# 887                 0       2    male  27.0
# 888                 1       1  female  19.0
# 889                 0       3  female   NaN
# 890                 1       1    male  26.0
# 891                 0       3    male  32.0
#
# [891 rows x 4 columns]

# %%
muertas = df['Survived'].count() - df['Survived'].sum()
muertas
# Out:
# 549

# %%
vivas = df['Survived'].sum()
vivas
# Out:
# 342

# %%
m_c1_female = df[(df['Survived'] == 0) & (df['Pclass'] == 1) & (df['Sex'] == 'female')]
hm_m_c1_female = m_c1_female.Survived.count()
m_c1_male = df[(df['Survived'] == 0) & (df['Pclass'] == 1) & (df['Sex'] == 'male')]
hm_m_c1_male = m_c1_male.Survived.count()
m_c2_female = df[(df['Survived'] == 0) & (df['Pclass'] == 2) & (df['Sex'] == 'female')]
hm_m_c2_female = m_c2_female.Survived.count()
m_c2_male = df[(df['Survived'] == 0) & (df['Pclass'] == 2) & (df['Sex'] == 'male')]
hm_m_c2_male = m_c2_male.Survived.count()
m_c3_female = df[(df['Survived'] == 0) & (df['Pclass'] == 3) & (df['Sex'] == 'female')]
hm_m_c3_female = m_c3_female.Survived.count()
m_c3_male = df[(df['Survived'] == 0) & (df['Pclass'] == 3) & (df['Sex'] == 'male')]
hm_m_c3_male = m_c3_male.Survived.count()

# %%
dic = {
    "muertes":
}
# Out:
# [3, 77, 6, 91, 72, 300]
