# %% [markdown]
# # Renombrar columnas

# %%
import pandas as pd

# %%
# Creamos el Dataframe a partir del dataset en CSV
df = pd.read_csv('titanic.csv', index_col = [0])

# %%
# Mostramos el Dataframe
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Podemos renombrar columnas con el método rename()
df.rename(columns = {
    'Sex':'Gender'
}, inplace = True)

# %%
# Mostramos el Dataframe
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Gender   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
# Podemos renombrar tanto el índice como los nombres de las columnas
# con los atributos index y columns
df.index.names=['Index']
df.columns.names=['Fields']

# %%
# Mostramos el Dataframe
df
# Out:
# Fields  Survived  Pclass                                               Name  \
# Index
# 1              0       3                            Braund, Mr. Owen Harris
# 2              1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3              1       3                             Heikkinen, Miss. Laina
# 4              1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5              0       3                           Allen, Mr. William Henry
# ...          ...     ...                                                ...
# 887            0       2                              Montvila, Rev. Juozas
# 888            1       1                       Graham, Miss. Margaret Edith
# 889            0       3           Johnston, Miss. Catherine Helen "Carrie"
# 890            1       1                              Behr, Mr. Karl Howell
# 891            0       3                                Dooley, Mr. Patrick
#
# ...
